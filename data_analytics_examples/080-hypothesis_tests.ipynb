# %% [markdown]
# # Hypothesis Tests (or significance tests)
# > Hypothesis tests are ubiquitous in statistics. They are used to determine whether there is enough evidence in a sample of data to infer that a certain condition is true for the entire population. Statistical hypothesis testing was invented a way ro protect researchers from being fooled by random chance.
#
# ## The Null Hypothesis
# > This is the baseline assumption that the treatments are equivalent, and any differences observed are due to random chance. This baseline assumption is called the **null hypothesis**, denoted $H_0$.
# > The hope then is, that we can in fact prove the null hypothesis *wrong*, and show that the outcomes for Group A and Be are more different than what chance might produce.
#
# ## Permutation (Resampling) Test — Intuitive Explanation
# In a permutation test, we simulate what would happen if the null hypothesis were true — that is, if both groups (A and B) actually came from the same distribution.
#
# Imagine we take all the results from Group A and Group B and toss them into one big basket.
# If the null hypothesis is true — meaning the treatment makes no real difference — then which result came from A or B shouldn’t matter at all.
#
# So, to test this assumption, we:
#
# 1. Shuffle the results randomly between two new groups of the same sizes as A and B.
# 2. Measure the difference between these new groups (e.g., in average conversion rate).
# 3. Repeat this shuffle thousands of times to see what kinds of differences we’d expect just by chance.
# 4. Finally, we compare our real observed difference to this “what-if” world of random chance.
#
# If our actual difference is far greater than almost all the shuffled ones, it’s unlikely to be random — giving us evidence that the groups truly differ, and the null hypothesis can be rejected.
#
# Technically, the **p-value** is the proportion of shuffled results that are as extreme or more extreme than your observed difference.
# If this proportion (p-value) is very small (e.g., < 0.05), it means the observed difference is unlikely to occur under random chance — providing evidence against $𝐻_0$.
#
# ### Storytelling Analogy
# * Think of your A/B test results as a deck of cards — some marked “A” and some “B,” each showing how well that user performed.
# * If the null hypothesis is true, the “A” and “B” labels don’t really matter — they’re just stickers on the cards. So, you shuffle the deck, deal it back into two new piles, and measure the difference again.
# * You repeat this shuffle many times, building up an idea of how big a difference you’d expect just by chance if A and B were really the same.
# * Now, if your real observed difference is much bigger than what usually happens in your shuffles, it’s like drawing a hand that’s astronomically rare — you’ve got good evidence that the treatments aren’t equivalent and that the effect is real, not random.
